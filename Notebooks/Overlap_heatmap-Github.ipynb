# %%
#!/usr/bin/env python3
import os
import re
import sys
print(sys.executable)
print(sys.path)
print(sys.version)

import collections
import argparse
#import tables
import itertools
import matplotlib
import glob
import math
# %matplotlib inline

import scipy.io
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import pandas as pd
import scipy
import scipy.stats as stats
import scipy.sparse as sp_sparse
import scanpy as sc 
import scanpy.external as sce

from collections import defaultdict
from scipy import sparse, io

import scanpy.external as sce
import matplotlib

from scipy.sparse import csr_matrix
from multiprocessing import Pool
#from matplotlib_venn import venn2, venn2_circles
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

print('numpy', np.__version__)
print('pandas', pd.__version__)
print('scipy', scipy.__version__)
print('matplotlib', matplotlib.__version__)
print('scanpy', sc.__version__)

# !date +%F
# Out:
# /home2/s426305/.conda/envs/py36/bin/python
# ['', '/cm/shared/apps/cnvkit/0.9.5/lib/python3.6/site-packages', '/cm/shared/apps/python/3.6.4-anaconda/lib', '/cm/shared/apps/jupyterkernel-matlab/0.16.1/lib/python3.6/site-packages', '/home2/s426305/.conda/envs/py36/lib/python36.zip', '/home2/s426305/.conda/envs/py36/lib/python3.6', '/home2/s426305/.conda/envs/py36/lib/python3.6/lib-dynload', '/home2/s426305/.local/lib/python3.6/site-packages', '/home2/s426305/.conda/envs/py36/lib/python3.6/site-packages', '/home2/s426305/.conda/envs/py36/lib/python3.6/site-packages/IPython/extensions', '/home2/s426305/.ipython']
# 3.6.7 | packaged by conda-forge | (default, Jul  2 2019, 02:18:42)
# [GCC 7.3.0]
# numpy 1.16.1
# pandas 0.25.1
# scipy 1.1.0
# matplotlib 3.3.3
# scanpy 1.4
# 2021-10-12

# %% [markdown]
# ## Load data
# ____

# %%
DATA_DIR = '../Data/'
clonal_pval = pd.read_pickle(DATA_DIR + 'Random_clonal_cells_overlap_pval_1000.pkl').astype(float)
non_clonal_pval = pd.read_pickle(DATA_DIR + 'Random_non-clonal_cells_overlap_pval_1000.pkl').astype(float)

# %%
#Clone region dict
Clone_region_dict = {}
Clone_dict_file = DATA_DIR + 'YWsg1P1-clone_tree.0.05.txt'
with open(Clone_dict_file) as f:
    first_line = f.readline()
    word = '}'
    for line in f:
        if not word in line:
            ID, clones = line.split(":")
            clone_IDs = clones.replace("'[", "").replace("]',", "").replace("'", "").strip(' \n')
            individual_clone_ID = clone_IDs.split(', ')
            for i in individual_clone_ID:
                Clone_region_dict.update({i: ID.strip("'")})

# %%
region_list = []
for i in clonal_pval.columns:
    region = Clone_region_dict[i]
    region_list.append(region)

# %%
x = collections.Counter(region_list)
most_common_region_list = sorted(x, key=x.get, reverse=True)

# %%
sort_size_index = []
for j in np.arange(len(most_common_region_list)):
    sort_index = [i for i, e in enumerate(region_list) if e == most_common_region_list[j]]
    for k in sort_index:
        sort_size_index.append(k)

# %%
len(sort_size_index)
# Out:
# 1000

# %%
clonal_pval.iloc[sort_size_index, sort_size_index]
# Out:
#                     CTCTCGATCCGAACGC-5  CTGAGCGGTAAGTTGA-2  \
# CTCTCGATCCGAACGC-5        1.384614e-94        3.050431e-70
# CTGAGCGGTAAGTTGA-2        3.050431e-70        3.194036e-80
# CGGGTCACACATATGC-2        1.875941e-82        9.653275e-68
# CTTACCGTCCTACGAA-5        1.136094e-83        3.793078e-75
# GCAACATTCTCCAATT-4        1.384614e-94        3.050431e-70
# ...                                ...                 ...
# GGCTTGGAGAAGCGAA-5        9.088675e-02        1.000000e+00
# TCGTCCAGTGTACAGG-5        1.000000e+00        1.000000e+00
# TTCGATTGTTGCTCAA-6        1.026447e-01        8.572075e-02
# CATGAGTTCCGGACTG-5        1.000000e+00        1.000000e+00
# AAATGGAGTTCAGTAC-6        1.000000e+00        1.000000e+00
#
#                     CGGGTCACACATATGC-2  CTTACCGTCCTACGAA-5  \
# CTCTCGATCCGAACGC-5        1.875941e-82        1.136094e-83
# CTGAGCGGTAAGTTGA-2        9.653275e-68        3.793078e-75
# CGGGTCACACATATGC-2        5.133938e-86        2.451545e-77
# CTTACCGTCCTACGAA-5        2.451545e-77        1.384614e-94
# GCAACATTCTCCAATT-4        1.875941e-82        1.136094e-83
# ...                                ...                 ...
# GGCTTGGAGAAGCGAA-5        8.187533e-02        9.088675e-02
# TCGTCCAGTGTACAGG-5        1.000000e+00        1.000000e+00
# TTCGATTGTTGCTCAA-6        9.252779e-02        1.026447e-01
# CATGAGTTCCGGACTG-5        1.000000e+00        1.000000e+00
# AAATGGAGTTCAGTAC-6        1.000000e+00        1.000000e+00
#
#                     GCAACATTCTCCAATT-4  GTTCGCTTCATCACCC-4  \
# CTCTCGATCCGAACGC-5        1.384614e-94        7.835883e-85
# CTGAGCGGTAAGTTGA-2        3.050431e-70        6.539789e-76
# CGGGTCACACATATGC-2        1.875941e-82        3.381604e-78
# CTTACCGTCCTACGAA-5        1.136094e-83        2.783904e-90
# GCAACATTCTCCAATT-4        1.384614e-94        7.835883e-85
# ...                                ...                 ...
# GGCTTGGAGAAGCGAA-5        9.088675e-02        8.789267e-02
# TCGTCCAGTGTACAGG-5        1.000000e+00        1.000000e+00
# TTCGATTGTTGCTCAA-6        1.026447e-01        9.928482e-02
# CATGAGTTCCGGACTG-5        1.000000e+00        1.000000e+00
# AAATGGAGTTCAGTAC-6        1.000000e+00        1.000000e+00
#
#                     CAGAGCCCAAGGGTCA-5  GTGGAGATCAGAGCGA-5  \
# CTCTCGATCCGAACGC-5        1.136094e-83        7.835883e-85
# CTGAGCGGTAAGTTGA-2        3.793078e-75        6.539789e-76
# CGGGTCACACATATGC-2        2.451545e-77        3.381604e-78
# CTTACCGTCCTACGAA-5        1.384614e-94        2.783904e-90
# GCAACATTCTCCAATT-4        1.136094e-83        7.835883e-85
# ...                                ...                 ...
# GGCTTGGAGAAGCGAA-5        9.088675e-02        8.789267e-02
# TCGTCCAGTGTACAGG-5        1.000000e+00        1.000000e+00
# TTCGATTGTTGCTCAA-6        1.026447e-01        9.928482e-02
# CATGAGTTCCGGACTG-5        1.000000e+00        1.000000e+00
# AAATGGAGTTCAGTAC-6        1.000000e+00        1.000000e+00
#
#                     CGGAACCCATGAGGGT-4  GTCGCGATCGACCTAA-2  ...  \
# CTCTCGATCCGAACGC-5        1.136094e-83        5.064313e-81  ...
# CTGAGCGGTAAGTTGA-2        3.793078e-75        1.127114e-71  ...
# CGGGTCACACATATGC-2        2.451545e-77        3.035461e-74  ...
# CTTACCGTCCTACGAA-5        1.384614e-94        2.798798e-86  ...
# GCAACATTCTCCAATT-4        1.136094e-83        5.064313e-81  ...
# ...                                ...                 ...  ...
# GGCTTGGAGAAGCGAA-5        9.088675e-02        8.488887e-02  ...
# TCGTCCAGTGTACAGG-5        1.000000e+00        1.000000e+00  ...
# TTCGATTGTTGCTCAA-6        1.026447e-01        9.591254e-02  ...
# CATGAGTTCCGGACTG-5        1.000000e+00        1.000000e+00  ...
# AAATGGAGTTCAGTAC-6        1.000000e+00        1.000000e+00  ...
#
#                     AAGTACCGTCTGTTAG-1  AGCTCAAGTTCCACGG-5  \
# CTCTCGATCCGAACGC-5                 1.0            0.084290
# CTGAGCGGTAAGTTGA-2                 1.0            0.070274
# CGGGTCACACATATGC-2                 1.0            0.075905
# CTTACCGTCCTACGAA-5                 1.0            0.084290
# GCAACATTCTCCAATT-4                 1.0            0.084290
# ...                                ...                 ...
# GGCTTGGAGAAGCGAA-5                 1.0            1.000000
# TCGTCCAGTGTACAGG-5                 1.0            1.000000
# TTCGATTGTTGCTCAA-6                 1.0            0.203870
# CATGAGTTCCGGACTG-5                 1.0            1.000000
# AAATGGAGTTCAGTAC-6                 1.0            1.000000
#
#                     GTGCTGGAGCTAGCCC-6  ACAGGGAGTGACATCT-1  \
# CTCTCGATCCGAACGC-5                 1.0                 1.0
# CTGAGCGGTAAGTTGA-2                 1.0                 1.0
# CGGGTCACACATATGC-2                 1.0                 1.0
# CTTACCGTCCTACGAA-5                 1.0                 1.0
# GCAACATTCTCCAATT-4                 1.0                 1.0
# ...                                ...                 ...
# GGCTTGGAGAAGCGAA-5                 1.0                 1.0
# TCGTCCAGTGTACAGG-5                 1.0                 1.0
# TTCGATTGTTGCTCAA-6                 1.0                 1.0
# CATGAGTTCCGGACTG-5                 1.0                 1.0
# AAATGGAGTTCAGTAC-6                 1.0                 1.0
#
#                     GAGGCAAAGTGTTGTC-5  GGCTTGGAGAAGCGAA-5  \
# CTCTCGATCCGAACGC-5                 1.0        9.088675e-02
# CTGAGCGGTAAGTTGA-2                 1.0        1.000000e+00
# CGGGTCACACATATGC-2                 1.0        8.187533e-02
# CTTACCGTCCTACGAA-5                 1.0        9.088675e-02
# GCAACATTCTCCAATT-4                 1.0        9.088675e-02
# ...                                ...                 ...
# GGCTTGGAGAAGCGAA-5                 1.0       5.282120e-192
# TCGTCCAGTGTACAGG-5                 1.0        1.000000e+00
# TTCGATTGTTGCTCAA-6                 1.0        1.000000e+00
# CATGAGTTCCGGACTG-5                 1.0        1.000000e+00
# AAATGGAGTTCAGTAC-6                 1.0        1.000000e+00
#
#                     TCGTCCAGTGTACAGG-5  TTCGATTGTTGCTCAA-6  \
# CTCTCGATCCGAACGC-5        1.000000e+00        1.026447e-01
# CTGAGCGGTAAGTTGA-2        1.000000e+00        8.572075e-02
# CGGGTCACACATATGC-2        1.000000e+00        9.252779e-02
# CTTACCGTCCTACGAA-5        1.000000e+00        1.026447e-01
# GCAACATTCTCCAATT-4        1.000000e+00        1.026447e-01
# ...                                ...                 ...
# GGCTTGGAGAAGCGAA-5        1.000000e+00        1.000000e+00
# TCGTCCAGTGTACAGG-5       2.054914e-199        1.000000e+00
# TTCGATTGTTGCTCAA-6        1.000000e+00       4.568653e-214
# CATGAGTTCCGGACTG-5        1.000000e+00        1.000000e+00
# AAATGGAGTTCAGTAC-6        1.000000e+00        1.000000e+00
#
#                     CATGAGTTCCGGACTG-5  AAATGGAGTTCAGTAC-6
# CTCTCGATCCGAACGC-5        1.000000e+00        1.000000e+00
# CTGAGCGGTAAGTTGA-2        1.000000e+00        1.000000e+00
# CGGGTCACACATATGC-2        1.000000e+00        1.000000e+00
# CTTACCGTCCTACGAA-5        1.000000e+00        1.000000e+00
# GCAACATTCTCCAATT-4        1.000000e+00        1.000000e+00
# ...                                ...                 ...
# GGCTTGGAGAAGCGAA-5        1.000000e+00        1.000000e+00
# TCGTCCAGTGTACAGG-5        1.000000e+00        1.000000e+00
# TTCGATTGTTGCTCAA-6        1.000000e+00        1.000000e+00
# CATGAGTTCCGGACTG-5       5.975929e-197        1.000000e+00
# AAATGGAGTTCAGTAC-6        1.000000e+00        2.139655e-71
#
# [1000 rows x 1000 columns]

# %%
fig, ax = plt.subplots(figsize= (40, 20))
plt.imshow(-np.log10(clonal_pval.iloc[sort_size_index, sort_size_index].astype(float)), cmap='Reds', vmax=50, rasterized=True)
plt.colorbar()
#plt.savefig(DATA_DIR + 'Overlap_heatmap-clonal_pval_sort.pdf')

# %% [markdown]
# ### Non-clonal
# ____

# %%
fig, ax = plt.subplots(figsize= (40, 20))
plt.imshow(-np.log10(non_clonal_pval.astype(float)), cmap='Reds', vmax=50, rasterized=True)
plt.colorbar()
plt.savefig(DATA_DIR + 'Plot_jupyter/Overlap_heatmap-non_clonal_pval.pdf')

# %% [markdown]
# ### D7 dataset
# ____

# %%
fig, ax = plt.subplots(figsize= (40, 20))
plt.imshow(-np.log10(D7_overlap.astype(float)), cmap='Reds', vmax=50, rasterized=True)
plt.colorbar()
plt.savefig(DATA_DIR + 'Plot_jupyter/Overlap_heatmap-D7_pval.pdf')
